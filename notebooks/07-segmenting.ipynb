# %% [markdown]
# # 07 Segmenting customers with advanced metrics

# %%
import json
import sqlalchemy
import pandas as pd

from pprint import pprint

# %%
import sqlalchemy
import pandas as pd

# Make a sql connection with sqlalchmey
conn_string = "postgresql://postgres-db/churn?user=postgres&password=password" 
engine = sqlalchemy.create_engine(conn_string)
conn = engine.connect()

# Query with Pandas, e.g. list all tables
df = pd.read_sql_query("SELECT * FROM information_schema.tables;", conn)
df.head()
# Out:
#   table_catalog table_schema     table_name  table_type  \
# 0         churn   socialnet7  active_period  BASE TABLE
# 1         churn   socialnet7     event_type  BASE TABLE
# 2         churn   socialnet7    metric_name  BASE TABLE
# 3         churn   socialnet7    active_week  BASE TABLE
# 4         churn   pg_catalog   pg_statistic  BASE TABLE
#
#   self_referencing_column_name reference_generation user_defined_type_catalog  \
# 0                         None                 None                      None
# 1                         None                 None                      None
# 2                         None                 None                      None
# 3                         None                 None                      None
# 4                         None                 None                      None
#
#   user_defined_type_schema user_defined_type_name is_insertable_into is_typed  \
# 0                     None                   None                YES       NO
# 1                     None                   None                YES       NO
# 2                     None                   None                YES       NO
# 3                     None                   None                YES       NO
# 4                     None                   None                YES       NO
#
#   commit_action
# 0          None
# 1          None
# 2          None
# 3          None
# 4          None

# %%
with open("/app/fightchurn/listings/conf/socialnet7_listings.json", "r") as f: 
    conf = json.loads(f.read())

chap7 = conf["chap7"]

# %% [markdown]
# ## Dependent Data

# %%
pprint(chap7)
# Out:
# {'defaults': {'%from_yyyy-mm-dd': '2020-03-01',
#               '%to_yyyy-mm-dd': '2020-05-10',
#               'mode': 'top',
#               'type': 'sql'},
#  'list1': {'insert': {'params': {'%den_metric': 'post_per_month',
#                                  '%new_metric_id': 21,
#                                  '%new_metric_name': 'adviw_per_post',
#                                  '%num_metric': 'adview_per_month'},
#                       'v1': {},
#                       'v2': {'%den_metric': 'message_per_month',
#                              '%new_metric_id': 22,
#                              '%new_metric_name': 'reply_per_message',
#                              '%num_metric': 'reply_per_month'},
#                       'v3': {'%new_metric_id': 23,
#                              '%new_metric_name': 'like_per_post',
#                              '%num_metric': 'like_per_month'},
#                       'v4': {'%den_metric': 'message_per_month',
#                              '%new_metric_id': 24,
#                              '%new_metric_name': 'post_per_message',
#                              '%num_metric': 'post_per_month'},
#                       'v5': {'%den_metric': 'newfriend_per_month',
#                              '%new_metric_id': 25,
#                              '%new_metric_name': 'unfriend_per_newfriend',
#                              '%num_metric': 'unfriend_per_month'},
#                       'v6': {'%den_metric': 'total_opinions',
#                              '%new_metric_id': 27,
#                              '%new_metric_name': 'dislike_percent',
#                              '%num_metric': 'dislike_per_month'},
#                       'v7': {'%den_metric': 'newfriend_per_month',
#                              '%new_metric_id': 28,
#                              '%new_metric_name': 'unfriend_per_newfriend_scaled',
#                              '%num_metric': 'unfriend_28day_avg_84day_obs_scaled'}},
#            'name': 'ratio_metric',
#            'params': {'%den_metric': 'post_per_month',
#                       '%num_metric': 'adview_per_month'}},
#  'list2': {'name': 'dataset2',
#            'params': {'%metric_interval': '7 day',
#                       'mode': 'save',
#                       'type': 'sql'}},
#  'list3': {'insert': {'params': {'%metric_list': " 'like_per_month', "
#                                                  "'dislike_per_month' ",
#                                  '%new_metric_id': 26,
#                                  '%new_metric_name': 'total_opinions'}},
#            'name': 'total_metric',
#            'params': {'%metric_list': " 'like_per_month', "
#                                       "'dislike_per_month' "}},
#  'list4': {'insert': {'params': {'%metric2measure': 'newfriend_per_month',
#                                  '%new_metric_id': 30,
#                                  '%new_metric_name': 'new_friends_pcnt_change',
#                                  '%period_weeks': 4}},
#            'name': 'percent_change_metric',
#            'params': {'%metric2measure': 'newfriend_per_month',
#                       '%period_weeks': 4}},
#  'list5': {'name': 'fat_tail_scores',
#            'params': {'data_set_path': 'socialnet7/socialnet7_dataset.csv',
#                       'type': 'py'},
#            'v2': {'data_set_path': 'socialnet7/socialnet7_dataset3_dumcat.csv'}},
#  'list6': {'insert': {'params': {'%event2measure': 'newfriend',
#                                  '%new_metric_id': 31,
#                                  '%new_metric_name': 'days_since_newfriend'}},
#            'name': 'days_since_event',
#            'params': {'%event2measure': 'newfriend',
#                       '%from_yyyy-mm-dd': '2020-05-03',
#                       '%to_yyyy-mm-dd': '2020-05-10'}},
#  'list7': {'insert': {'params': {'%desc_period': 28,
#                                  '%event2measure': 'unfriend',
#                                  '%new_metric_id': 33,
#                                  '%obs_period': 84}},
#            'name': 'scaled_events_per_month',
#            'params': {'%desc_period': 32,
#                       '%event2measure': 'unfriend',
#                       '%obs_period': 84}},
#  'list8': {'insert': {'params': {'%desc_period': 28,
#                                  '%event2measure': 'unfriend',
#                                  '%min_tenure': 14,
#                                  '%new_metric_id': 34,
#                                  '%obs_period': 84},
#                       'v1': {}},
#            'name': 'tenure_scaled_events_per_month',
#            'params': {'%desc_period': 28,
#                       '%event2measure': 'unfriend',
#                       '%from_yyyy-mm-dd': '2020-05-10',
#                       '%min_tenure': 14,
#                       '%obs_period': 84,
#                       '%to_yyyy-mm-dd': '2020-05-10',
#                       'mode': 'save'}}}
